# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def getPeakGain(gain, lengths, p):
    maxGain = 0
    for i in range(1, len(gain)):
        if(maxGain < gain[i]):
            maxGain = gain[i]
            lengthMaxGain = lengths[i-1]
    print("Player: "+ str(p) + " peak gain: " + str(maxGain) + " at length: " + str(lengthMaxGain))   
    
# sort list1 - use the indexes of the sorted list1 to rearrage list2    
def getCombinedPlot(list1, list2, xlabel, ylabel, showPlot = True, legend = " "):
    idx   = np.argsort(list1)
    list1 = np.array(list1)[idx]
    list2 = np.array(list2)[idx]
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(np.arange(min(list1), max(list1)+1, 1.0))
    plt.plot(list1, list2, 'o-', label=legend)
    if showPlot == True:
        plt.show()
        
    return (list1, list2)

def readFromFile(path, mode):
    results = [0] * 100
    f = open(path, "r")
    player = -1
    for x in f:
        line = x.split(',')
        if mode==1 or len(line) == 31:
            if int(line[0]) == player:
                results[player].append(line)
            else:
                player = int(line[0])
                results[player] = []
                results[player].append(line)
    f.close()
    return results

def plotOneResult(players, results, idx, label):
    for p in players:
        tmp = results[p]
        values = []
        for words in tmp:
            values.append(float(words[idx]))
        values =  [x for i, x in enumerate(values) if i == values.index(x)]
        x = list(range(0, len(values)))
        plt.plot(x, values, 'o-', label= label + str(p))
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()
    
# a list with the results at idx for the given player    
def getResultPerPlayer(p, results, idx, unique ):
    tmp = results[p]
    values = []
    for words in tmp:
        values.append(float(words[idx]))
    if (unique == True):
        values =  [x for i, x in enumerate(values) if i == values.index(x)]
    return values


def EffortPerBodyPartPerPlayer(p, results, batchSize):
    bodyParts =[ [0]*1 for i in range(7)]
    tmp = results[p]
    counter = 0
    for words in tmp:            
        for i in range (7):
            bodyParts[i][bodyParts[i].index(bodyParts[i][-1])] += float(words[21+i])
            
        counter = counter + 1
        if counter == batchSize:
            counter = 0
        if counter == 0:
            for i in range(7):
                bodyParts[i][bodyParts[i].index(bodyParts[i][-1])] /= batchSize
                bodyParts[i].append(0)
    return bodyParts

# %%
# player 0 = all the shit
# player 1 = something
# player 2 = spiral - random targets
# player 3 = circle - selected targets
# player 4 = spiral - selected targets
# player 5 = circle - selected targets + closer targets
# player 6 = same
# player 7 = 
# player 8 = change effort 
# player 9 = same as 8 

batchSize = 8
players = [ 1]
pathA = "E:\\Andreea\\Projects\\Git\\SmartsuitWrapper\\SmartuistWrapper\\tapResultParticipants.csv"
pathATest = "E:\\Andreea\\Projects\\Git\\SmartsuitWrapper\\SmartuistWrapper\\tapResult.csv"
pathStatsATest = "E:\\\\Andreea\\\\Projects\\\\Git\\\\SmartsuitWrapper\\\\SmartuistWrapper\\\\GradientStats.csv"
pathStatsA = "E:\\\\Andreea\\\\Projects\\\\Git\\\\SmartsuitWrapper\\\\SmartuistWrapper\\\\GradientStatsParticipants.csv"

pathH = "C:\\Users\\huber\\OneDrive\\Dokumenty\\thesis-hubert\\unity\\SmartuistWrapper\\tapResultParticipants.csv"
pathHTest = "C:\\Users\\huber\\OneDrive\\Dokumenty\\thesis-hubert\\unity\\SmartuistWrapper\\tapResult.csv"
pathStatsHTest = "C:\\Users\\huber\\OneDrive\\Dokumenty\\thesis-hubert\\unity\\SmartuistWrapper\\GradientStats.csv"
pathStatsH = "C:\\Users\\huber\\OneDrive\\Dokumenty\\thesis-hubert\\unity\\SmartuistWrapper\\\GradientStatsParticipants.csv"
plt.rcParams['figure.figsize'] = [20, 5]
maxGain = 0

# read tap results / player
# results = readFromFile(pathH, 0)
results = readFromFile(pathHTest, 0)
# read gradient results / player
# gradientStats = readFromFile(pathStatsH, 1)
gradientStats = readFromFile(pathStatsHTest, 1)

for p in players:
    tmp = results[p]
    prevLength = 1
    lengths = []
    gain = []
    delta = []
    th = []
    totalTime = 0
    for words in tmp:
        totalTime += float(words[10])
        lengths.append(float(words[28]))
        gain.append(float(words[29]))
        th.append(float(words[11]))      
       # print("Player: "+ str(p) + " gain: " + words[29] + " at length: " + words[28])      

    uniqueLengths = [x for i, x in enumerate(lengths) if i == lengths.index(x)]
    x = list(range(0, len(uniqueLengths)))   
    plt.plot(x, uniqueLengths, 'o-', label=p)
    
    uniqueGain = [x for i, x in enumerate(gain) if i == gain.index(x)]
    getPeakGain(uniqueGain, uniqueLengths, p)
    print(p, "Total time", totalTime/60000)

plt.legend(loc='upper left')
plt.grid(True)
plt.show()


for p in players:
    tmp = gradientStats[p]
    gain = []
    gainEff = []
    gainTh = []
    for words in tmp:
        gain.append(float(words[5]))
        gainTh.append(float(words[3]))
        gainEff.append(float(words[2]))

   
    x = list(range(0, len(gain)))
    plt.plot(x, gain, 'o-', label="Gain"+str(p))
   # plt.plot(x, gainTh, 'o-', label="gainTh"+str(p))
   # plt.plot(x, gainEff, 'o-', label="gainEff"+str(p))
    
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

for p in players:
    bodyParts = EffortPerBodyPartPerPlayer(p, results, 10)
    z = 0
    x = list(range(0, len(bodyParts[0])-2))
    for a in bodyParts:
        if z in [0,1,2,3,4,5,6]:
            plt.plot(x,a[:len(a)-2], 'o-', label= str(p) + "-" + str(z))
        z = z + 1
        
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()     
    
# plot learning rate
plotOneResult(players, gradientStats, 6, "lr-")


for p in players:
    tmp = gradientStats[p]
    gain = [0]
    prevGain = [0]
    for words in tmp:
        gain.append(float(words[5]))
        prevGain.append(float(words[4]))
    delta = np.array(gain) - np.array(prevGain)    
    x = list(range(0, len(delta)))
    plt.plot(x, delta, 'o-', label="DeltaCreated"+str(p))

# plot delta
plotOneResult(players, results, 30, "Delta-")
# Out:
# Player: 1 peak gain: 34.80852 at length: 5.615261
# 1 Total time 3.91475
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-b2e85b04b705> in <module>
#      64     gainEff = []
#      65     gainTh = []
# ---> 66     for words in tmp:
#      67         gain.append(float(words[5]))
#      68         gainTh.append(float(words[3]))
#
# TypeError: 'int' object is not iterable

# %%
from scipy.interpolate import make_interp_spline, BSpline, pchip

def inter(x,y, points):
    xnew = np.linspace(x.min(),x.max(),points) #300 represents number of points to make between T.min and T.max

    spl = pchip(x, y) #BSpline object
    newY = spl(xnew)
    return(xnew,newY)

# %%
for p in players:
    uniqueLengths = getResultPerPlayer(p, results, 28, True )
    
    gain = getResultPerPlayer(p, results, 29, True )
    for i in range(len(lengths)-1, 1, -1):   
        lengths[i] = lengths[i-1]
    (x,y) = getCombinedPlot(uniqueLengths[1:], gain[1:], "Arm length-"+str(p), "Gain ") 

    (x,y) = inter(x, y,25)
   
    plt.plot(x,y)
    plt.ylabel("Gain interpolated")
    plt.xlabel("Arm length")
    plt.show()
    
    gainEffort = getResultPerPlayer(p, gradientStats, 2, False )
    effort = [1/x for x in gainEffort]
    #getCombinedPlot(uniqueLengths, gainEffort, "Arm length-"+str(p), "gainEffort") 
    getCombinedPlot(uniqueLengths, effort, "Arm length-"+str(p), "Total Effort") 
    
    #body, LeftUpperArm, RightUpperArm, RightFoot, LeftFoot, LeftHand, RightHand
   # bodyParts = EffortPerBodyPartPerPlayer(p, results, 10)
   # getCombinedPlot(uniqueLengths, bodyParts[0], "Arm length-"+str(p), "effort Body") 
   # getCombinedPlot(uniqueLengths, bodyParts[1], "Arm length-"+str(p), "effort Upper Arm", False, "Left") 
   # getCombinedPlot(uniqueLengths, bodyParts[2], "Arm length-"+str(p), "effort Upper Arm", False, "Right") 
   # plt.show()
   # getCombinedPlot(uniqueLengths, bodyParts[5], "lengths-"+str(p), "effortLeftHand") 
   # getCombinedPlot(uniqueLengths, bodyParts[6], "lengths-"+str(p), "effortRightHand")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-e99dac326de4> in <module>
#      18     effort = [1/x for x in gainEffort]
#      19     #getCombinedPlot(uniqueLengths, gainEffort, "Arm length-"+str(p), "gainEffort")
# ---> 20     getCombinedPlot(uniqueLengths, effort, "Arm length-"+str(p), "Total Effort")
#      21
#      22     #body, LeftUpperArm, RightUpperArm, RightFoot, LeftFoot, LeftHand, RightHand
#
# <ipython-input-44-8ed21f1dae51> in getCombinedPlot(list1, list2, xlabel, ylabel, showPlot, legend)
#      11     idx   = np.argsort(list1)
#      12     list1 = np.array(list1)[idx]
# ---> 13     list2 = np.array(list2)[idx]
#      14
#      15     plt.xlabel(xlabel)
#
# IndexError: index 32 is out of bounds for axis 1 with size 32

# %%
from scipy.stats import linregress
player = 60
uniqueLengths = getResultPerPlayer(player, results, 28, True )
x = list(range(0, len(uniqueLengths)))
print("Avg length: ", sum(uniqueLengths)/ len(uniqueLengths))
slope, intercept, r_value, p_value, std_err = linregress(x, uniqueLengths)
print(linRegress)
y = [i * slope + intercept for i in x]
print("Mean", np.mean(y))
plt.plot(x, uniqueLengths, 'o', label='original data')
plt.plot(x, y  , 'r', label='fitted line')
plt.legend()
plt.show()

# %%
Player: 52 peak gain: 23.31818 at length: 7.649506
Player: 62 peak gain: 15.85158 at length: 6.547279
Player: 63 peak gain: 17.4942 at length: 5.256552

# %%
#GRAPHS#
players = [ 52,36]

SMALL_SIZE = 20
MEDIUM_SIZE = 20
BIGGER_SIZE = 24

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

for p in players:
    tmp = results[p]
    prevLength = 1
    lengths = []
    gain = []
    delta = []
    th = []
    totalTime = 0
    for words in tmp:
        totalTime += float(words[10])
        lengths.append(float(words[28]))
        gain.append(float(words[29]))
        th.append(float(words[11]))      
       # print("Player: "+ str(p) + " gain: " + words[29] + " at length: " + words[28])      

    uniqueLengths = [x for i, x in enumerate(lengths) if i == lengths.index(x)]
    x = list(range(0, len(uniqueLengths)))   
    plt.plot(x, uniqueLengths, 'o-', label=p)
    uniqueGain = [x for i, x in enumerate(gain) if i == gain.index(x)]

plt.title('Diveregence of arms\' lengths', {'fontsize': BIGGER_SIZE})
plt.legend(("long", "short"), loc='upper left')
plt.xlabel("Lesson")
plt.ylabel("Length multiplier")
plt.grid(True)
plt.savefig("DivergenceOfLengths",bbox_inches='tight', dpi=150)
plt.show()

# %%
players = [8]

for p in players:
    tmp = results[p]
    prevLength = 1
    lengths = []
    gain = []
    delta = []
    th = []
    totalTime = 0
    for words in tmp:
        totalTime += float(words[10])
        lengths.append(float(words[28]))
        gain.append(float(words[29]))
        th.append(float(words[11]))      
       # print("Player: "+ str(p) + " gain: " + words[29] + " at length: " + words[28])      

    uniqueLengths = [x for i, x in enumerate(lengths) if i == lengths.index(x)]
    x = list(range(0, len(uniqueLengths)))   
    plt.plot(x, uniqueLengths, 'o-', label=p)
    uniqueGain = [x for i, x in enumerate(gain) if i == gain.index(x)]

plt.title('Undesired elongation behaviour', {'fontsize': BIGGER_SIZE})
# plt.legend(("Internal evaluator"), loc='upper left')
plt.xlabel("Lesson")
plt.ylabel("Length multiplier")
plt.grid(True)
plt.savefig("ProportionalMultiplier",bbox_inches='tight', dpi=150)
plt.show()

# %%
players = [14]

for p in players:
    tmp = results[p]
    prevLength = 1
    lengths = []
    gain = []
    delta = []
    th = []
    totalTime = 0
    for words in tmp:
        totalTime += float(words[10])
        lengths.append(float(words[28]))
        gain.append(float(words[29]))
        th.append(float(words[11]))      
       # print("Player: "+ str(p) + " gain: " + words[29] + " at length: " + words[28])      

    uniqueLengths = [x for i, x in enumerate(lengths) if i == lengths.index(x)]
    x = list(range(0, len(uniqueLengths)))   
    plt.plot(x, uniqueLengths, 'o-', label=p)
    uniqueGain = [x for i, x in enumerate(gain) if i == gain.index(x)]

plt.title('Desired elongation behaviour', {'fontsize': BIGGER_SIZE})
# plt.legend(loc='upper left')
plt.xlabel("Lesson")
plt.ylabel("Length multiplier")
plt.grid(True)
plt.savefig("InversedProportionalMultipier",bbox_inches='tight', dpi=150)
Splt.show()

# %%
# Subplots not used 

players = [47,48,49,50]

fig, axs = plt.subplots(2,sharex=True)
fig.suptitle('Vertically stacked subplots')


for p in players:
    tmp = results[p]
    prevLength = 1
    lengths = []
    gain = []
    delta = []
    th = []
    totalTime = 0
    for words in tmp:
        totalTime += float(words[10])
        lengths.append(float(words[28]))
        gain.append(float(words[29]))
        th.append(float(words[11]))      
       # print("Player: "+ str(p) + " gain: " + words[29] + " at length: " + words[28])      

    uniqueLengths = [x for i, x in enumerate(lengths) if i == lengths.index(x)]
    x = list(range(0, len(uniqueLengths)))   
    axs[0].plot(x, uniqueLengths, 'o-', label=p)
    uniqueGain = [x for i, x in enumerate(gain) if i == gain.index(x)]

# plt.title('Desired elongation behaviour', {'fontsize': BIGGER_SIZE})
fig.legend(loc='upper left')
# plt.xlabel("Lesson")
# plt.ylabel("Length multiplier")
# plt.grid(True)
# plt.savefig("LearningRateSmall",bbox_inches='tight', dpi=150)
# plt.show()



for p in players:
    tmp = gradientStats[p]
    gain = []
    gainEff = []
    gainTh = []
    for words in tmp:
        gain.append(float(words[5]))
        gainTh.append(float(words[3]))
        gainEff.append(float(words[2]))

   
    x = list(range(0, len(gain)))
    (xnew,ynew) = inter(np.array(x), gain,11)

    axs[1].plot( xnew, ynew)
   # plt.plot(x, gainTh, 'o-', label="gainTh"+str(p))
   # plt.plot(x, gainEff, 'o-', label="gainEff"+str(p))
    
plt.legend(loc='upper left')
axs[1].grid(True)
axs[0].grid(True)
axs[0].set_yticklabels([])
axs[1].set_yticklabels([])
plt.show()

# %%
fig = plt.figure()
ax = plt.subplot(111)


for p in players:
    tmp = gradientStats[p]
    gain = []
    gainEff = []
    gainTh = []
    for words in tmp:
        gain.append(float(words[5]))
        gainTh.append(float(words[3]))
        gainEff.append(float(words[2]))
  
    x = list(range(0, len(gain)))
    (xnew,ynew) = inter(np.array(x), gain,11)
    ax.plot( xnew, ynew)


box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(("0.05","0.085", "0.11", "0.13"), title="Initial value", loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('The effect of the learning rate on the fitness function', {'fontsize': BIGGER_SIZE})    
plt.xlabel("Lesson")
plt.ylabel("Fitness")
plt.grid(True)
plt.savefig("LearningRateSmall",bbox_inches='tight', dpi=150)
plt.show()
